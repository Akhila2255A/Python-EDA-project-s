# %% [markdown]
# !pip install pandas

# %%
# !pip install pandas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
dataset = pd.read_csv(r"C:\Users\91988\Downloads\data scientist\bike sharing data.csv")

# %% [markdown]
# # Data Exploration:

# %%
dataset.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
dataset.tail()
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 726      727  2012-12-27       1   1    12        0        4           1
# 727      728  2012-12-28       1   1    12        0        5           1
# 728      729  2012-12-29       1   1    12        0        6           0
# 729      730  2012-12-30       1   1    12        0        0           0
# 730      731  2012-12-31       1   1    12        0        1           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 726           2  0.254167  0.226642  0.652917   0.350133     247        1867
# 727           2  0.253333  0.255046  0.590000   0.155471     644        2451
# 728           2  0.253333  0.242400  0.752917   0.124383     159        1182
# 729           1  0.255833  0.231700  0.483333   0.350754     364        1432
# 730           2  0.215833  0.223487  0.577500   0.154846     439        2290
#
#       cnt
# 726  2114
# 727  3095
# 728  1341
# 729  1796
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    object
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.5+ KB

# %%
dataset.describe()
# Out:
#           instant      season          yr        mnth     holiday     weekday  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean   366.000000    2.496580    0.500684    6.519836    0.028728    2.997264
# std    211.165812    1.110807    0.500342    3.451913    0.167155    2.004787
# min      1.000000    1.000000    0.000000    1.000000    0.000000    0.000000
# 25%    183.500000    2.000000    0.000000    4.000000    0.000000    1.000000
# 50%    366.000000    3.000000    1.000000    7.000000    0.000000    3.000000
# 75%    548.500000    3.000000    1.000000   10.000000    0.000000    5.000000
# max    731.000000    4.000000    1.000000   12.000000    1.000000    6.000000
#
#        workingday  weathersit        temp       atemp         hum   windspeed  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean     0.683995    1.395349    0.495385    0.474354    0.627894    0.190486
# ...

# %%
dataset.shape
# Out:
# (731, 16)

# %%
dataset.shape[0] #columns
# Out:
# 731

# %%
dataset.shape[1] #rows
# Out:
# 16

# %%
dataset.index
# Out:
# RangeIndex(start=0, stop=731, step=1)

# %%
dataset.columns
# Out:
# Index(['instant', 'dteday', 'season', 'yr', 'mnth', 'holiday', 'weekday',
#        'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed',
#        'casual', 'registered', 'cnt'],
#       dtype='object')

# %% [markdown]
# # Data Cleaning:

# %%
dataset.isnull()
# Out:
#      instant  dteday  season     yr   mnth  holiday  weekday  workingday  \
# 0      False   False   False  False  False    False    False       False
# 1      False   False   False  False  False    False    False       False
# 2      False   False   False  False  False    False    False       False
# 3      False   False   False  False  False    False    False       False
# 4      False   False   False  False  False    False    False       False
# ..       ...     ...     ...    ...    ...      ...      ...         ...
# 726    False   False   False  False  False    False    False       False
# 727    False   False   False  False  False    False    False       False
# 728    False   False   False  False  False    False    False       False
# 729    False   False   False  False  False    False    False       False
# 730    False   False   False  False  False    False    False       False
#
#      weathersit   temp  atemp    hum  windspeed  casual  registered    cnt
# ...

# %%
dataset.isna().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
dataset.isnull().any()
# Out:
# instant       False
# dteday        False
# season        False
# yr            False
# mnth          False
# holiday       False
# weekday       False
# workingday    False
# weathersit    False
# temp          False
# atemp         False
# hum           False
# windspeed     False
# casual        False
# registered    False
# cnt           False
# dtype: bool

# %%
dataset=dataset.drop_duplicates()
dataset
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  2011-01-01       1   0     1        0        6           0
# 1          2  2011-01-02       1   0     1        0        0           0
# 2          3  2011-01-03       1   0     1        0        1           1
# 3          4  2011-01-04       1   0     1        0        2           1
# 4          5  2011-01-05       1   0     1        0        3           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 726      727  2012-12-27       1   1    12        0        4           1
# 727      728  2012-12-28       1   1    12        0        5           1
# 728      729  2012-12-29       1   1    12        0        6           0
# 729      730  2012-12-30       1   1    12        0        0           0
# 730      731  2012-12-31       1   1    12        0        1           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# ...

# %%
dataset.weathersit.mean()
# Out:
# 1.3953488372093024

# %%
dataset.weathersit.median()
# Out:
# 1.0

# %% [markdown]
# # Explorarory Data Analysis¶

# %%
dataset.head(2)
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
#
#    cnt
# 0  985
# 1  801

# %%
dataset.nunique()
# Out:
# instant       731
# dteday        731
# season          4
# yr              2
# mnth           12
# holiday         2
# weekday         7
# workingday      2
# weathersit      3
# temp          499
# atemp         690
# hum           595
# windspeed     650
# casual        606
# registered    679
# cnt           696
# dtype: int64

# %%
#To find total number of unique valuse present in column DiscountsAvailed.
dataset.season.nunique()
# Out:
# 4

# %%
#To find all uique values
dataset.season.unique() #(1:winter, 2:spring, 3:summer, 4:fall)
# Out:
# array([1, 2, 3, 4], dtype=int64)

# %%
dataset[dataset.season == 3]
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 171      172  2011-06-21       3   0     6        0        2           1
# 172      173  2011-06-22       3   0     6        0        3           1
# 173      174  2011-06-23       3   0     6        0        4           1
# 174      175  2011-06-24       3   0     6        0        5           1
# 175      176  2011-06-25       3   0     6        0        6           0
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 626      627  2012-09-18       3   1     9        0        2           1
# 627      628  2012-09-19       3   1     9        0        3           1
# 628      629  2012-09-20       3   1     9        0        4           1
# 629      630  2012-09-21       3   1     9        0        5           1
# 630      631  2012-09-22       3   1     9        0        6           0
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# ...

# %%
dataset[dataset.dteday == '2011-06-25']
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 175      176  2011-06-25       3   0     6        0        6           0
#
#      weathersit   temp     atemp       hum  windspeed  casual  registered  \
# 175           1  0.695  0.643313  0.483333   0.209571    1782        3420
#
#       cnt
# 175  5202

# %%
dataset[dataset["mnth"].isin([6])]  #data of female customers
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 151      152  2011-06-01       2   0     6        0        3           1
# 152      153  2011-06-02       2   0     6        0        4           1
# 153      154  2011-06-03       2   0     6        0        5           1
# 154      155  2011-06-04       2   0     6        0        6           0
# 155      156  2011-06-05       2   0     6        0        0           0
# 156      157  2011-06-06       2   0     6        0        1           1
# 157      158  2011-06-07       2   0     6        0        2           1
# 158      159  2011-06-08       2   0     6        0        3           1
# 159      160  2011-06-09       2   0     6        0        4           1
# 160      161  2011-06-10       2   0     6        0        5           1
# 161      162  2011-06-11       2   0     6        0        6           0
# 162      163  2011-06-12       2   0     6        0        0           0
# ...

# %% [markdown]
# # Value_count()¶

# %%
dataset.value_counts()
# Out:
# instant  dteday      season  yr  mnth  holiday  weekday  workingday  weathersit  temp      atemp     hum       windspeed  casual  registered  cnt
# 1        2011-01-01  1       0   1     0        6        0           2           0.344167  0.363625  0.805833  0.160446   331     654         985     1
# 481      2012-04-25  2       1   4     0        3        1           1           0.476667  0.470317  0.427917  0.118792   655     5541        6196    1
# 483      2012-04-27  2       1   4     0        5        1           1           0.457500  0.452637  0.400833  0.347633   1014    5219        6233    1
# 484      2012-04-28  2       1   4     0        6        0           2           0.376667  0.377504  0.489583  0.129975   1120    3100        4220    1
# 485      2012-04-29  2       1   4     0        0        0           1           0.458333  0.450121  0.587083  0.116908   2229    4075        6304    1
# ...

# %%
dataset.yr.value_counts() #(0: 2011, 1:2012)
# Out:
# yr
# 1    366
# 0    365
# Name: count, dtype: int64

# %%
#filtering
dataset[dataset.workingday ==1]
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 2          3  2011-01-03       1   0     1        0        1           1
# 3          4  2011-01-04       1   0     1        0        2           1
# 4          5  2011-01-05       1   0     1        0        3           1
# 5          6  2011-01-06       1   0     1        0        4           1
# 6          7  2011-01-07       1   0     1        0        5           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 723      724  2012-12-24       1   1    12        0        1           1
# 725      726  2012-12-26       1   1    12        0        3           1
# 726      727  2012-12-27       1   1    12        0        4           1
# 727      728  2012-12-28       1   1    12        0        5           1
# 730      731  2012-12-31       1   1    12        0        1           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# ...

# %%
dataset[dataset.index.isin(range(30,40))]
# Out:
#     instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 30       31  2011-01-31       1   0     1        0        1           1
# 31       32  2011-02-01       1   0     2        0        2           1
# 32       33  2011-02-02       1   0     2        0        3           1
# 33       34  2011-02-03       1   0     2        0        4           1
# 34       35  2011-02-04       1   0     2        0        5           1
# 35       36  2011-02-05       1   0     2        0        6           0
# 36       37  2011-02-06       1   0     2        0        0           0
# 37       38  2011-02-07       1   0     2        0        1           1
# 38       39  2011-02-08       1   0     2        0        2           1
# 39       40  2011-02-09       1   0     2        0        3           1
#
#     weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 30           2  0.180833  0.186250  0.603750   0.187192      42        1459
# ...

# %%
#To find the index
dataset[dataset.index== 4]
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp    atemp       hum  windspeed  casual  registered  \
# 4           1  0.226957  0.22927  0.436957     0.1869      82        1518
#
#     cnt
# 4  1600

# %%
dataset[dataset.cnt >=2000]
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 46        47  2011-02-16       1   0     2        0        3           1
# 47        48  2011-02-17       1   0     2        0        4           1
# 48        49  2011-02-18       1   0     2        0        5           1
# 57        58  2011-02-27       1   0     2        0        0           0
# 60        61  2011-03-02       1   0     3        0        3           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 719      720  2012-12-20       4   1    12        0        4           1
# 720      721  2012-12-21       1   1    12        0        5           1
# 726      727  2012-12-27       1   1    12        0        4           1
# 727      728  2012-12-28       1   1    12        0        5           1
# 730      731  2012-12-31       1   1    12        0        1           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# ...

# %%
dataset[dataset.cnt == 2729]
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 730      731  2012-12-31       1   1    12        0        1           1
#
#      weathersit      temp     atemp     hum  windspeed  casual  registered  \
# 730           2  0.215833  0.223487  0.5775   0.154846     439        2290
#
#       cnt
# 730  2729

# %%
# maximim values and minimum values of FoodRating
min_value = dataset["windspeed"].min()
max_value = dataset["windspeed"].max()

print("The lowest speed: ",min_value)
print("The highest speed : ",max_value)
# Out:
# The lowest speed:  0.0223917
# The highest speed :  0.507463

# %%
sorted_df = dataset.sort_values(by='temp', ascending=False)
sorted_df.head(5)
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 553      554  2012-07-07       3   1     7        0        6           0
# 203      204  2011-07-23       3   0     7        0        6           0
# 202      203  2011-07-22       3   0     7        0        5           1
# 209      210  2011-07-29       3   0     7        0        5           1
# 545      546  2012-06-29       3   1     6        0        5           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 553           1  0.861667  0.804913  0.492083   0.163554    1448        3392
# 203           1  0.849167  0.804287  0.500000   0.131221     987        2298
# 202           1  0.848333  0.840896  0.580417   0.133100     562        2825
# 209           1  0.838333  0.785967  0.542500   0.174138     670        3176
# 545           1  0.834167  0.786613  0.488750   0.165417     829        4634
#
#       cnt
# 553  4840
# 203  3285
# 202  3387
# 209  3846
# ...

# %% [markdown]
# # Visualization

# %%
plt.style.use('bmh')
dataset = pd.read_csv(r"C:\Users\91988\Downloads\data scientist\bike sharing data.csv")

# %%
x = dataset['season']
y = dataset['weekday']
plt.xlabel('Season',fontsize=24)
plt.ylabel('weekday', fontsize=24)
plt.bar(x,y)
# Out:
# <BarContainer object of 731 artists>

# %%
sns.set(color_codes=True)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    object
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.5+ KB

# %% [markdown]
# # Displot

# %%
sns.displot(dataset['atemp'])

# %%
sns.distplot(dataset['hum'])
# Out:
# <Axes: xlabel='hum', ylabel='Density'>

# %%
dataset = np.random.randn(100)
xyz = pd.Series(dataset,name="temp")
plot = sns.distplot(xyz,kde=True)
plt.show()

# %%
data = pd.DataFrame(dataset) 
  
X = list(data.iloc[:, 0]) 
Y = list(data.iloc[:, 1]) 
  
# Plot the data using bar() method 
plt.bar(X, Y, color='g') 
plt.title("Bike Sharing Data") 
plt.xlabel("dteday") 
plt.ylabel("yr") 
  
# Show the plot 
plt.show()

# %% [markdown]
# # Python Seaborn For Statistical Analysis
# # 1. seaborn.scatterplot()¶

# %%
data = pd.read_csv(r"C:\Users\91988\Downloads\data scientist\bike sharing data.csv")
res = sns.scatterplot(x="weathersit", y="dteday", data=dataset)
plt.show()

# %% [markdown]
# # Seaborn Lineplot

# %%
res = sns.lineplot(x="yr", y="hum", data=dataset)
plt.show()

# %% [markdown]
# # Boxplot

# %%
# check for outliers in the dataset
sns.boxplot(dataset["temp"])
# Out:
# <Axes: >

# %%
#catplot()
res = sns.catplot(x="temp", y="holiday", data=dataset)
plt.show()

# %% [markdown]
# # Violinplot

# %%
res = sns.violinplot(x=dataset['weekday'])
plt.show()

# %% [markdown]
# # Seaborn Boxplot()

# %%
res = sns.boxplot(x=dataset['casual'])
plt.show()

# %% [markdown]
# # Countplot

# %%
res = sns.countplot(x=dataset['season'])
plt.show()

# %% [markdown]
# # Pointplot()

# %%
res = sns.pointplot(x=dataset['weekday'], y=dataset['workingday'])
plt.show()

# %%
dt2=dataset.head(20)
sns.pairplot(dt2[['workingday','weathersit','temp','atemp','hum','windspeed']])

# %% [markdown]
# # Donut Chart
# Donut chart is a modified pie chart,with an area from center cut out.

# %%
C=dataset['yr'].value_counts()
print(C)
# Out:
# yr
# 1    366
# 0    365
# Name: count, dtype: int64

# %%
dataset.head(3)
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
#
#     cnt
# 0   985
# 1   801
# 2  1349

# %%
type(C)
# Out:
# pandas.core.series.Series

# %%
#The data is taken from variable 'B'
plt.pie(C, labels=['1','0'],colors=['pink','green','yellow','blue','violet'],startangle = 30, shadow =True, radius=1,
       autopct= '%1.2f%%',pctdistance = 0.85) #autopct shows the percentage on the chart upto required decimal points.
# Out:
# ([<matplotlib.patches.Wedge at 0x1f98c37d650>,
# ...
#  [Text(-0.5520458510198293, 0.9514438387901792, '1'),
#   Text(0.5520459401004287, -0.951443787103912, '0')],
#  [Text(-0.4265808848789589, 0.7352066027015021, '50.07%'),
#   Text(0.4265809537139676, -0.7352065627621137, '49.93%')])

# %%
#Histplot()
sns.histplot(dataset["temp"])
# Out:
# <Axes: xlabel='temp', ylabel='Count'>
