# %%
# !pip install pandas

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv(r"C:\Users\91988\Downloads\data scientist\restaurant_customer_satisfaction.csv")

# %% [markdown]
# # Data Exploration:

# %%
data.head()
# Out:
#    CustomerID  Age  Gender  Income VisitFrequency  AverageSpend  \
# 0         654   35    Male   83380         Weekly     27.829142
# 1         655   19    Male   43623         Rarely    115.408622
# 2         656   41  Female   83737         Weekly    106.693771
# 3         657   43    Male   96768         Rarely     43.508508
# 4         658   55  Female   67937        Monthly    148.084627
#
#   PreferredCuisine TimeOfVisit  GroupSize DiningOccasion  MealType  \
# 0          Chinese   Breakfast          3       Business  Takeaway
# 1         American      Dinner          1         Casual   Dine-in
# 2         American      Dinner          6    Celebration   Dine-in
# 3           Indian       Lunch          1    Celebration   Dine-in
# 4          Chinese   Breakfast          1       Business  Takeaway
#
#    OnlineReservation  DeliveryOrder  LoyaltyProgramMember   WaitTime  \
# 0                  0              1                     1  43.523929
# ...

# %%
data.tail()
# Out:
#       CustomerID  Age  Gender  Income VisitFrequency  AverageSpend  \
# 1495        2149   39    Male  114857        Monthly    163.015254
# 1496        2150   37  Female  133506         Weekly    190.991911
# 1497        2151   46    Male  119159        Monthly    150.088604
# 1498        2152   24    Male   27970         Weekly    196.363626
# 1499        2153   51    Male  148333         Weekly    171.119498
#
#      PreferredCuisine TimeOfVisit  GroupSize DiningOccasion  MealType  \
# 1495         American       Lunch          2       Business   Dine-in
# 1496          Italian       Lunch          4         Casual  Takeaway
# 1497         American       Lunch          4         Casual   Dine-in
# 1498          Italian      Dinner          6         Casual   Dine-in
# 1499          Chinese   Breakfast          4         Casual   Dine-in
#
#       OnlineReservation  DeliveryOrder  LoyaltyProgramMember   WaitTime  \
# ...

# %%
data.describe()
# Out:
#         CustomerID          Age         Income  AverageSpend    GroupSize  \
# count  1500.000000  1500.000000    1500.000000   1500.000000  1500.000000
# mean   1403.500000    43.832000   85921.890000    105.659004     5.035333
# std     433.157015    14.967157   38183.051749     52.381849     2.558864
# min     654.000000    18.000000   20012.000000     10.306127     1.000000
# 25%    1028.750000    31.750000   52444.000000     62.287907     3.000000
# 50%    1403.500000    44.000000   85811.000000    104.626408     5.000000
# 75%    1778.250000    57.000000  119159.250000    148.649330     7.000000
# max    2153.000000    69.000000  149875.000000    199.973527     9.000000
#
#        OnlineReservation  DeliveryOrder  LoyaltyProgramMember     WaitTime  \
# count        1500.000000    1500.000000           1500.000000  1500.000000
# mean            0.296667       0.405333              0.480000    30.163550
# std             0.456941       0.491120              0.499766    17.214184
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   CustomerID            1500 non-null   int64
#  1   Age                   1500 non-null   int64
#  2   Gender                1500 non-null   object
#  3   Income                1500 non-null   int64
#  4   VisitFrequency        1500 non-null   object
#  5   AverageSpend          1500 non-null   float64
#  6   PreferredCuisine      1500 non-null   object
#  7   TimeOfVisit           1500 non-null   object
#  8   GroupSize             1500 non-null   int64
#  9   DiningOccasion        1500 non-null   object
#  10  MealType              1500 non-null   object
#  11  OnlineReservation     1500 non-null   int64
#  12  DeliveryOrder         1500 non-null   int64
#  13  LoyaltyProgramMember  1500 non-null   int64
#  14  WaitTime              1500 non-null   float64
# ...

# %%
data.shape
# Out:
# (1500, 19)

# %%
data.shape[0]
# Out:
# 1500

# %%
data.shape[1]
# Out:
# 19

# %%
data.index
# Out:
# RangeIndex(start=0, stop=1500, step=1)

# %%
data.columns
# Out:
# Index(['CustomerID', 'Age', 'Gender', 'Income', 'VisitFrequency',
#        'AverageSpend', 'PreferredCuisine', 'TimeOfVisit', 'GroupSize',
#        'DiningOccasion', 'MealType', 'OnlineReservation', 'DeliveryOrder',
#        'LoyaltyProgramMember', 'WaitTime', 'ServiceRating', 'FoodRating',
#        'AmbianceRating', 'HighSatisfaction'],
#       dtype='object')

# %% [markdown]
# # Data Cleaning:

# %%
data.head(3)
# Out:
#    CustomerID  Age  Gender  Income VisitFrequency  AverageSpend  \
# 0         654   35    Male   83380         Weekly    695.728550
# 1         655   19    Male   43623         Rarely   3846.954077
# 2         656   41  Female   83737         Weekly   2133.875423
#
#   PreferredCuisine TimeOfVisit  GroupSize DiningOccasion  MealType  \
# 0          Chinese   Breakfast          3       Business  Takeaway
# 1         American      Dinner          1         Casual   Dine-in
# 2         American      Dinner          6    Celebration   Dine-in
#
#    OnlineReservation  DeliveryOrder  LoyaltyProgramMember   WaitTime  \
# 0                  0              1                     1  43.523929
# 1                  0              0                     0  57.524294
# 2                  0              1                     0  48.682623
#
#    ServiceRating  FoodRating  AmbianceRating  HighSatisfaction  counts_per
# 0              2           5               4                 0       100.0
# ...

# %%
data.isnull()
# Out:
#       CustomerID    Age  Gender  PreferredCuisine  VisitTiming  GroupSize  \
# 0          False  False   False             False        False      False
# 1          False  False   False             False        False      False
# 2          False  False   False             False        False      False
# 3          False  False   False             False        False      False
# 4          False  False   False             False        False      False
# ...          ...    ...     ...               ...          ...        ...
# 1495       False  False   False             False        False      False
# 1496       False  False   False             False        False      False
# 1497       False  False   False             False        False      False
# 1498       False  False   False             False        False      False
# 1499       False  False   False             False        False      False
#
#       DiningOccasion  OnlineReservation  LoyaltyProgramMember  WaitTime  \
# ...

# %%
data.isna().sum()
# Out:
# CustomerID              0
# Age                     0
# Gender                  0
# Income                  0
# VisitFrequency          0
# AverageSpend            0
# PreferredCuisine        0
# TimeOfVisit             0
# GroupSize               0
# DiningOccasion          0
# MealType                0
# OnlineReservation       0
# DeliveryOrder           0
# LoyaltyProgramMember    0
# WaitTime                0
# ServiceRating           0
# FoodRating              0
# AmbianceRating          0
# HighSatisfaction        0
# dtype: int64

# %%
data.isnull().any()
# Out:
# CustomerID              False
# Age                     False
# Gender                  False
# Income                  False
# VisitFrequency          False
# AverageSpend            False
# PreferredCuisine        False
# TimeOfVisit             False
# GroupSize               False
# DiningOccasion          False
# MealType                False
# OnlineReservation       False
# DeliveryOrder           False
# LoyaltyProgramMember    False
# WaitTime                False
# ServiceRating           False
# FoodRating              False
# AmbianceRating          False
# HighSatisfaction        False
# dtype: bool

# %%
data=data.drop_duplicates()
data
# Out:
#       CustomerID  Age  Gender PreferredCuisine TimeOfVisit  GroupSize  \
# 0            654   35    Male          Chinese   Breakfast          3
# 1            655   19    Male         American      Dinner          1
# 2            656   41  Female         American      Dinner          6
# 3            657   43    Male           Indian       Lunch          1
# 4            658   55  Female          Chinese   Breakfast          1
# ...          ...  ...     ...              ...         ...        ...
# 1495        2149   39    Male         American       Lunch          2
# 1496        2150   37  Female          Italian       Lunch          4
# 1497        2151   46    Male         American       Lunch          4
# 1498        2152   24    Male          Italian      Dinner          6
# 1499        2153   51    Male          Chinese   Breakfast          4
#
#      DiningOccasion  OnlineReservation  LoyaltyProgramMember   WaitTime  \
# ...

# %%
data.ServiceRating.mean()
# Out:
# 3.044

# %%
data.ServiceRating.median()
# Out:
# 3.0

# %%
data.drop(columns = "AmbianceRating")
# Out:
#       CustomerID  Age  Gender PreferredCuisine VisitTiming  GroupSize  \
# 0            654   35    Male          Chinese   Breakfast          3
# 1            655   19    Male         American      Dinner          1
# 2            656   41  Female         American      Dinner          6
# 3            657   43    Male           Indian       Lunch          1
# 4            658   55  Female          Chinese   Breakfast          1
# ...          ...  ...     ...              ...         ...        ...
# 1495        2149   39    Male         American       Lunch          2
# 1496        2150   37  Female          Italian       Lunch          4
# 1497        2151   46    Male         American       Lunch          4
# 1498        2152   24    Male          Italian      Dinner          6
# 1499        2153   51    Male          Chinese   Breakfast          4
#
#      DiningOccasion  OnlineReservation  LoyaltyProgramMember   WaitTime  \
# ...

# %%
data["TimeOfVisit"].str.strip()
# Out:
# 0       Breakfast
# 1          Dinner
# 2          Dinner
# 3           Lunch
# 4       Breakfast
#           ...
# 1495        Lunch
# 1496        Lunch
# 1497        Lunch
# 1498       Dinner
# 1499    Breakfast
# Name: TimeOfVisit, Length: 1500, dtype: object

# %%
#rename of column name
data.rename(columns={"TimeOfVisit":"VisitingTime"},inplace =True)

# %% [markdown]
# # Explorarory Data Analysis

# %%
# Check the  unique values in the coulumn "GroupSize"
data.GroupSize.unique()
# Out:
# array([3, 1, 6, 8, 5, 9, 4, 2, 7], dtype=int64)

# %%
data.head(1)
# Out:
#    CustomerID  Age Gender  Income VisitFrequency  AverageSpend  \
# 0         654   35   Male   83380         Weekly     27.829142
#
#   PreferredCuisine TimeOfVisit  GroupSize DiningOccasion  MealType  \
# 0          Chinese   Breakfast          3       Business  Takeaway
#
#    OnlineReservation  DeliveryOrder  LoyaltyProgramMember   WaitTime  \
# 0                  0              1                     1  43.523929
#
#    ServiceRating  FoodRating  AmbianceRating  HighSatisfaction
# 0              2           5               4                 0

# %%
data.WaitTime.nunique()
# Out:
# 1500

# %%
data.WaitTime.unique()
# Out:
# array([43.52392853, 57.52429446, 48.68262293, ...,  3.9257852 ,
#        24.22803783, 39.40216309])

# %%
#Choose the maximum quanties to fill the outlies
max_WaitTime = data["WaitTime"].quantile(0.995)
max_WaitTime       #maximum quantile we use
# Out:
# 59.705532021403044

# %%
data.nunique()
# Out:
# CustomerID              1500
# Age                       52
# Gender                     2
# Income                  1486
# VisitFrequency             4
# AverageSpend            1500
# PreferredCuisine           5
# TimeOfVisit                3
# GroupSize                  9
# DiningOccasion             3
# MealType                   2
# OnlineReservation          2
# DeliveryOrder              2
# LoyaltyProgramMember       2
# WaitTime                1500
# ServiceRating              5
# FoodRating                 5
# AmbianceRating             5
# HighSatisfaction           2
# dtype: int64

# %%
data.head(3)
# Out:
#    CustomerID  Age  Gender  Income VisitFrequency  AverageSpend  \
# 0         654   35    Male   83380         Weekly    695.728550
# 1         655   19    Male   43623         Rarely   3846.954077
# 2         656   41  Female   83737         Weekly   2133.875423
#
#   PreferredCuisine TimeOfVisit  GroupSize DiningOccasion  MealType  \
# 0          Chinese   Breakfast          3       Business  Takeaway
# 1         American      Dinner          1         Casual   Dine-in
# 2         American      Dinner          6    Celebration   Dine-in
#
#    OnlineReservation  DeliveryOrder  LoyaltyProgramMember   WaitTime  \
# 0                  0              1                     1  43.523929
# 1                  0              0                     0  57.524294
# 2                  0              1                     0  48.682623
#
#    ServiceRating  FoodRating  AmbianceRating  HighSatisfaction  counts_per
# 0              2           5               4                 0       100.0
# ...

# %%
data[data.index.isin(range(10,20))]
# Out:
#     CustomerID  Age  Gender  Income VisitFrequency  AverageSpend  \
# 10         664   21    Male   79249        Monthly     39.235383
# 11         665   59    Male   94208         Weekly    132.994918
# 12         666   32  Female  143471        Monthly    156.130808
# 13         667   69    Male   38433          Daily     46.136865
# 14         668   58    Male   64870        Monthly     88.939098
# 15         669   54  Female  135616         Rarely    112.007541
# 16         670   59  Female  123325         Weekly     63.939240
# 17         671   42    Male   25569        Monthly    120.390191
# 18         672   26  Female  120447         Weekly     52.110324
# 19         673   58    Male   70458         Rarely    197.370534
#
#    PreferredCuisine TimeOfVisit  GroupSize DiningOccasion  MealType  \
# 10         American   Breakfast          5       Business  Takeaway
# 11          Italian      Dinner          8         Casual   Dine-in
# ...

# %%
data['counts_per'] = data.Gender.str.split().str.get(0)

data['MealType'] = data.Gender.str.split().str.get(1) + data.Gender.str.split().str.get(2)
data[['Gender','counts_per','MealType']]
# Out:
#       Gender counts_per  MealType
# 0       Male       Male       NaN
# 1       Male       Male       NaN
# 2     Female     Female       NaN
# 3       Male       Male       NaN
# 4     Female     Female       NaN
# ...      ...        ...       ...
# 1495    Male       Male       NaN
# 1496  Female     Female       NaN
# 1497    Male       Male       NaN
# 1498    Male       Male       NaN
# 1499    Male       Male       NaN
#
# [1500 rows x 3 columns]

# %%
print(data.VisitFrequency.unique())
# Out:
# ['Weekly' 'Rarely' 'Monthly' 'Daily']

# %%
searchfor = ['Weekly']
data[data.VisitFrequency.str.contains('|'.join(searchfor))].head(5)
# Out:
#    CustomerID  Age  Gender  Income VisitFrequency  AverageSpend  \
# 0         654   35    Male   83380         Weekly    695.728550
# 2         656   41  Female   83737         Weekly   2133.875423
# 6         660   20  Female  131104         Weekly  12023.670672
# 7         661   51  Female  137882         Weekly   5365.969934
# 8         662   27    Male  149638         Weekly   1131.172639
#
#   PreferredCuisine TimeOfVisit  GroupSize DiningOccasion  MealType  \
# 0          Chinese   Breakfast          3       Business       NaN
# 2         American      Dinner          6    Celebration       NaN
# 6           Indian       Lunch          6       Business       NaN
# 7          Mexican      Dinner          6       Business       NaN
# 8           Indian   Breakfast          5    Celebration       NaN
#
#    OnlineReservation  DeliveryOrder  LoyaltyProgramMember   WaitTime  \
# 0                  0              1                     1  43.523929
# ...

# %% [markdown]
# # Analysis About Restaurant:

# %%
data.head(2)
# Out:
#    CustomerID  Age Gender  Income VisitFrequency  AverageSpend  \
# 0         654   35   Male   83380         Weekly    695.728550
# 1         655   19   Male   43623         Rarely   3846.954077
#
#   PreferredCuisine TimeOfVisit  GroupSize DiningOccasion  MealType  \
# 0          Chinese   Breakfast          3       Business  Takeaway
# 1         American      Dinner          1         Casual   Dine-in
#
#    OnlineReservation  DeliveryOrder  LoyaltyProgramMember   WaitTime  \
# 0                  0              1                     1  43.523929
# 1                  0              0                     0  57.524294
#
#    ServiceRating  FoodRating  AmbianceRating  HighSatisfaction  counts_per
# 0              2           5               4                 0       100.0
# 1              5           5               3                 0       100.0

# %%
data.head()
data[data["VisitFrequency"] == "Weekly"]
data[data["Gender"] == "Female"]
# Out:
#       CustomerID  Age  Gender  Income VisitFrequency  AverageSpend  \
# 2            656   41  Female   83737         Weekly   2133.875423
# 4            658   55  Female   67937        Monthly   2961.692544
# 5            659   42  Female   28860        Monthly   3702.156527
# 6            660   20  Female  131104         Weekly  12023.670672
# 7            661   51  Female  137882         Weekly   5365.969934
# ...          ...  ...     ...     ...            ...           ...
# 1485        2139   63  Female  142579         Rarely   2895.814878
# 1486        2140   24  Female  109032        Monthly   1599.256701
# 1488        2142   25  Female  138277        Monthly   3800.269361
# 1494        2148   25  Female  142332         Weekly   4287.559467
# 1496        2150   37  Female  133506         Weekly   9549.595539
#
#      PreferredCuisine TimeOfVisit  GroupSize DiningOccasion  MealType  \
# 2            American      Dinner          6    Celebration   Dine-in
# ...

# %%
data[data["PreferredCuisine"]== "Indian"]
# Out:
#       CustomerID  Age  Gender  Income VisitFrequency  AverageSpend  \
# 3            657   43    Male   96768         Rarely   4350.850773
# 6            660   20  Female  131104         Weekly  12023.670672
# 8            662   27    Male  149638         Weekly   1131.172639
# 21           675   40  Female   85259        Monthly   1229.133172
# 34           688   47  Female   50567          Daily   2032.988486
# ...          ...  ...     ...     ...            ...           ...
# 1478        2132   42    Male  101871        Monthly  16909.193563
# 1480        2134   31    Male  130898         Weekly   1633.300615
# 1486        2140   24  Female  109032        Monthly   1599.256701
# 1490        2144   20    Male  106717         Rarely   3510.790678
# 1491        2145   47    Male   90569         Weekly  10131.205301
#
#      PreferredCuisine TimeOfVisit  GroupSize DiningOccasion  MealType  \
# 3              Indian       Lunch          1    Celebration   Dine-in
# ...

# %%
data[data.Income >100000]
# Out:
#       CustomerID  Age  Gender  Income VisitFrequency  AverageSpend  \
# 6            660   20  Female  131104         Weekly    120.236707
# 7            661   51  Female  137882         Weekly    160.979098
# 8            662   27    Male  149638         Weekly     56.558632
# 9            663   32  Female  136145         Weekly     65.753455
# 12           666   32  Female  143471        Monthly    156.130808
# ...          ...  ...     ...     ...            ...           ...
# 1494        2148   25  Female  142332         Weekly    128.626784
# 1495        2149   39    Male  114857        Monthly    163.015254
# 1496        2150   37  Female  133506         Weekly    190.991911
# 1497        2151   46    Male  119159        Monthly    150.088604
# 1499        2153   51    Male  148333         Weekly    171.119498
#
#      PreferredCuisine TimeOfVisit  GroupSize DiningOccasion  MealType  \
# 6              Indian       Lunch          6       Business   Dine-in
# ...

# %%
data[data["PreferredCuisine"].isin(["Indian","American"])]
# Out:
#       CustomerID  Age  Gender PreferredCuisine VisitTiming  GroupSize  \
# 1            655   19    Male         American      Dinner          1
# 2            656   41  Female         American      Dinner          6
# 3            657   43    Male           Indian       Lunch          1
# 6            660   20  Female           Indian       Lunch          6
# 8            662   27    Male           Indian   Breakfast          5
# ...          ...  ...     ...              ...         ...        ...
# 1490        2144   20    Male           Indian   Breakfast          5
# 1491        2145   47    Male           Indian       Lunch          9
# 1494        2148   25  Female         American      Dinner          4
# 1495        2149   39    Male         American       Lunch          2
# 1497        2151   46    Male         American       Lunch          4
#
#      DiningOccasion  OnlineReservation  LoyaltyProgramMember   WaitTime  \
# ...

# %%
data[data["Gender"].isin(["Female"])]  #data of female customers
# Out:
#       CustomerID  Age  Gender PreferredCuisine VisitTiming  GroupSize  \
# 2            656   41  Female         American      Dinner          6
# 4            658   55  Female          Chinese   Breakfast          1
# 5            659   42  Female          Chinese      Dinner          8
# 6            660   20  Female           Indian       Lunch          6
# 7            661   51  Female          Mexican      Dinner          6
# ...          ...  ...     ...              ...         ...        ...
# 1485        2139   63  Female         American       Lunch          5
# 1486        2140   24  Female           Indian       Lunch          6
# 1488        2142   25  Female         American       Lunch          7
# 1494        2148   25  Female         American      Dinner          4
# 1496        2150   37  Female          Italian       Lunch          4
#
#      DiningOccasion  OnlineReservation  LoyaltyProgramMember   WaitTime  \
# ...

# %%
data[data["Age"] > 50].head(5)
# Out:
#     CustomerID  Age  Gender PreferredCuisine VisitTiming  GroupSize  \
# 4          658   55  Female          Chinese   Breakfast          1
# 7          661   51  Female          Mexican      Dinner          6
# 11         665   59    Male          Italian      Dinner          8
# 13         667   69    Male          Italian      Dinner          4
# 14         668   58    Male         American       Lunch          2
#
#    DiningOccasion  OnlineReservation  LoyaltyProgramMember   WaitTime  \
# 4        Business                  0                     1  37.789041
# 7        Business                  1                     0  56.447210
# 11         Casual                  0                     1  55.045475
# 13       Business                  0                     1  20.243443
# 14    Celebration                  0                     1  58.271648
#
#     AmbianceRating  HighSatisfaction
# 4                5                 0
# 7                3                 0
# ...

# %%
data.head()
# Out:
#    CustomerID  Age  Gender  Income VisitFrequency  AverageSpend  \
# 0         654   35    Male   83380         Weekly     27.829142
# 1         655   19    Male   43623         Rarely    115.408622
# 2         656   41  Female   83737         Weekly    106.693771
# 3         657   43    Male   96768         Rarely     43.508508
# 4         658   55  Female   67937        Monthly    148.084627
#
#   PreferredCuisine TimeOfVisit  GroupSize DiningOccasion  MealType  \
# 0          Chinese   Breakfast          3       Business  Takeaway
# 1         American      Dinner          1         Casual   Dine-in
# 2         American      Dinner          6    Celebration   Dine-in
# 3           Indian       Lunch          1    Celebration   Dine-in
# 4          Chinese   Breakfast          1       Business  Takeaway
#
#    OnlineReservation  DeliveryOrder  LoyaltyProgramMember   WaitTime  \
# 0                  0              1                     1  43.523929
# ...

# %%
# maximim values and minimum values of FoodRating
min_value = data["FoodRating"].min()
max_value = data["FoodRating"].max()

print("minimum rating of food : ",min_value)
print("maximum rating of food : ",max_value)
# Out:
# minimum rating of food :  1
# maximum rating of food :  5

# %%
# Sorting the dataset in descending order on the basis of salary
# displaying unsorted data frame 
print("\nBefore sorting:")
print(data) 
  
# sort data frame 
data.sort_values(["Income"],  
                    axis=0, 
                    ascending=[False],  
                    inplace=True) 
  
# displaying sorted data frame 
print("\nAfter sorting:") 
print(data)
# Out:
# Before sorting:
#       CustomerID  Age  Gender  Income VisitFrequency  AverageSpend  \
# 861         1515   40    Male  149875         Weekly    116.279303
# 1122        1776   45  Female  149856         Rarely     44.519643
# 1272        1926   31  Female  149807         Rarely    167.184428
# 570         1224   32  Female  149728        Monthly    156.869604
# 884         1538   56    Male  149720         Weekly     51.888609
# ...          ...  ...     ...     ...            ...           ...
# 978         1632   34    Male   20381         Weekly     12.836971
# 280          934   46    Male   20312          Daily     46.101730
# 522         1176   55  Female   20150         Rarely    114.734866
# 323          977   57    Male   20093         Weekly    166.165108
# 811         1465   49  Female   20012         Weekly    158.638696
#
#      PreferredCuisine TimeOfVisit  GroupSize DiningOccasion  MealType  \
# 861            Indian       Lunch          8    Celebration   Dine-in
# ...

# %%
highest_Income = data["Income"].max()
print("The highest Income :",highest_Income)
# Out:
# The highest Income : 149875

# %% [markdown]
# # Visualization

# %%
data.head(2)
# Out:
#    CustomerID  Age Gender  Income VisitFrequency  AverageSpend  \
# 0         654   35   Male   83380         Weekly     27.829142
# 1         655   19   Male   43623         Rarely    115.408622
#
#   PreferredCuisine TimeOfVisit  GroupSize DiningOccasion  MealType  \
# 0          Chinese   Breakfast          3       Business  Takeaway
# 1         American      Dinner          1         Casual   Dine-in
#
#    OnlineReservation  DeliveryOrder  LoyaltyProgramMember   WaitTime  \
# 0                  0              1                     1  43.523929
# 1                  0              0                     0  57.524294
#
#    ServiceRating  FoodRating  AmbianceRating  HighSatisfaction
# 0              2           5               4                 0
# 1              5           5               3                 0

# %%
plt.style.use('bmh')
data = pd.read_csv(r"C:\Users\91988\Downloads\data scientist\restaurant_customer_satisfaction.csv")

# %%
x = data['ServiceRating']
y = data['AmbianceRating']
plt.xlabel('ServiceRating',fontsize=24)
plt.ylabel('AmbianceRating', fontsize=24)
plt.bar(x,y)
# Out:
# <BarContainer object of 1500 artists>

# %%
sns.set(color_codes=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   CustomerID            1500 non-null   int64
#  1   Age                   1500 non-null   int64
#  2   Gender                1500 non-null   object
#  3   Income                1500 non-null   int64
#  4   VisitFrequency        1500 non-null   object
#  5   AverageSpend          1500 non-null   float64
#  6   PreferredCuisine      1500 non-null   object
#  7   TimeOfVisit           1500 non-null   object
#  8   GroupSize             1500 non-null   int64
#  9   DiningOccasion        1500 non-null   object
#  10  MealType              1500 non-null   object
#  11  OnlineReservation     1500 non-null   int64
#  12  DeliveryOrder         1500 non-null   int64
#  13  LoyaltyProgramMember  1500 non-null   int64
#  14  WaitTime              1500 non-null   float64
# ...

# %%
# Displot()

# %%
sns.displot(data['ServiceRating'])

# %%
data = np.random.randn(100)
set = pd.Series(data,name="DeliveryOrder")
plot = sns.distplot(set,kde=True)
plt.show()

# %%
#Using Bar method showing the Plot

# %%
data = pd.DataFrame(dt) 
  
X = list(data.iloc[:, 0]) 
Y = list(data.iloc[:, 1]) 
  
# Plot the data using bar() method 
plt.bar(X, Y, color='g') 
plt.title("Restaurant Data") 
plt.xlabel("GroupSize") 
plt.ylabel("WaitTime") 
  
# Show the plot 
plt.show()

# %% [markdown]
# # Python Seaborn For Statistical Analysis

# %% [markdown]
# # 1. seaborn.scatterplot()

# %%
data = pd.read_csv(r"C:\Users\91988\Downloads\data scientist\restaurant_customer_satisfaction.csv")
res = seaborn.scatterplot(x="PreferredCuisine", y="GroupSize", data=data)
plt.show()

# %% [markdown]
# # lineplot()

# %%
res = sns.lineplot(x="PreferredCuisine", y="GroupSize", data=data)
plt.show()

# %% [markdown]
# # Catplot()

# %%
res = sns.catplot(x="FoodRating", y="DeliveryOrder", data=data)
plt.show()

# %% [markdown]
# # Seaborn Swarmplot()

# %%
res = sns.swarmplot(x="GroupSize", y="Gender", data=data)
 
plt.show()

# %% [markdown]
# # Seaborn Violinplot

# %%
res = sns.violinplot(x=data['Age'])
plt.show()

# %% [markdown]
# # Boxplot()

# %%
res = sns.boxplot(x=data['AmbianceRating'])
plt.show()

# %% [markdown]
# # CountPlot()

# %%
res = sns.countplot(x=data['MealType'])
plt.show()

# %% [markdown]
# # PointPlot()

# %%
res = sns.pointplot(x=data['DiningOccasion'], y=data['Income'])
plt.show()

# %%
data.head(2)
# Out:
#    CustomerID  Age Gender  Income VisitFrequency  AverageSpend  \
# 0         654   35   Male   83380         Weekly     27.829142
# 1         655   19   Male   43623         Rarely    115.408622
#
#   PreferredCuisine TimeOfVisit  GroupSize DiningOccasion  MealType  \
# 0          Chinese   Breakfast          3       Business  Takeaway
# 1         American      Dinner          1         Casual   Dine-in
#
#    OnlineReservation  DeliveryOrder  LoyaltyProgramMember   WaitTime  \
# 0                  0              1                     1  43.523929
# 1                  0              0                     0  57.524294
#
#    ServiceRating  FoodRating  AmbianceRating  HighSatisfaction
# 0              2           5               4                 0
# 1              5           5               3                 0

# %% [markdown]
# # Donut Chart
# Donut chart is a modified pie chart,with an area from center cut out.

# %%
A=dt['PreferredCuisine'].value_counts()
print(A)
# Out:
# PreferredCuisine
# Italian     325
# Chinese     310
# Mexican     299
# Indian      296
# American    270
# Name: count, dtype: int64

# %%
type(A)
# Out:
# pandas.core.series.Series

# %%
#The data is taken from variable 'B'
plt.pie(A, labels=["Italian","Chinese","Mexican","Indian","American"],colors=['pink','green','yellow','blue','black'],startangle = 30, shadow =True, radius=1,
       autopct= '%1.2f%%',pctdistance = 0.75) #autopct shows the percentage on the chart upto required decimal points.
# Out:
# ([<matplotlib.patches.Wedge at 0x196e40b61d0>,
# ...
#  [Text(0.3942047380899026, 1.0269384716074628, 'Italian'),
#   Text(-0.9032641312226234, 0.6277849227614817, 'Chinese'),
#   Text(-0.8634919248866731, -0.681455571299779, 'Mexican'),
#   Text(0.37044330509523093, -1.035746956408814, 'Indian'),
#   Text(1.0990351163864314, -0.04606314089880908, 'American')],
#  [Text(0.2687759577885699, 0.7001853215505427, '21.67%'),
#   Text(-0.6158619076517886, 0.4280351746101011, '20.67%'),
#   Text(-0.5887444942409135, -0.4646287986134856, '19.93%'),
#   Text(0.25257498074674833, -0.7061911066423732, '19.73%'),
#   Text(0.7493421248089304, -0.031406686976460735, '18.00%')])

# %% [markdown]
# # Boxplot()

# %%
# check for outliers in the dataset
sns.boxplot(data["WaitTime"])
# Out:
# <Axes: >

# %%
dt1=data.head(20)
sns.pairplot(dt1[['Age', 'GroupSize', 'WaitTime', 'FoodRating','LoyaltyProgramMember',]])

# %%
sns.histplot(data["WaitTime"])
# Out:
# <Axes: xlabel='WaitTime', ylabel='Count'>
